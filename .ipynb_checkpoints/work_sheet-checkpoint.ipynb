# %% [markdown]
# # work sheet

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from mask_functions import rle2mask
from glob import glob
import pydicom

# %% [markdown]
# ## convert csv to numpy

# %%
mask_csv = pd.read_csv('/data/pneumo/train-rle.csv')

# %%
rle2mask(mask_csv.iloc[0]['ImageId'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-1274dbb48a82> in <module>
# ----> 1 rle2mask(mask_csv.iloc[0]['ImageId'])
#
# TypeError: rle2mask() missing 2 required positional arguments: 'width' and 'height'

# %%
dcm_path = '/data/pneumo/dicom-images-train/*/*/*'

# %%
dcm_path_list = glob(dcm_path)

# %%
index = 5
target_path = dcm_path_list[index]
target_id = dcm_path_list[index].split('/')[-1].split('.dcm')[0]

# %%
dataset = pydicom.dcmread(target_path)

# %%
img = dataset.pixel_array
print(img.shape)
height, width = img.shape
# Out:
# (1024, 1024)

# %%
rle = mask_csv[mask_csv['ImageId'] == target_id][' EncodedPixels'].iloc[0]
# print(rle)
mask = rle2mask(rle, height, width)

# %%
mask_csv[mask_csv['ImageId'] == target_id][' EncodedPixels'].values
# Out:
# array([' 503035 2 1022 5 1016 9 1013 11 1012 12 1010 14 1009 15 1008 17 1007 17 1006 18 1005 19 1004 20 1004 20 1003 21 1002 22 1002 21 1002 22 1002 22 1002 22 1001 23 1001 22 1001 23 1001 22 1001 23 1001 22 1001 22 1002 22 1002 21 1002 22 1002 21 1002 21 1003 20 1003 20 1003 20 1004 19 1004 18 1005 18 1005 18 1004 18 1005 18 1005 18 1004 20 1003 20 1003 20 1004 19 1004 20 1003 20 1004 19 1005 19 1005 18 1005 19 1005 18 1006 18 1006 18 1006 18 1006 17 1007 17 1008 16 1008 16 1008 16 1008 16 1008 16 1009 16 1008 16 1008 16 1008 16 1008 16 1009 15 1009 15 1010 14 1010 14 1011 13 1011 13 1012 12 1012 12 1012 12 1013 11 1013 12 1013 11 1013 11 1013 11 1014 10 1014 10 1015 9 1015 9 1016 8 1016 8 1017 7 1017 7 1017 7 1018 6 1018 6 1019 5 1019 5 1020 4 1021 3 1022 2',
#        ' 869217 4 3 8 1007 22 1000 28 995 31 993 34 990 40 984 45 978 49 975 51 973 53 971 55 969 57 967 59 965 60 964 62 963 62 962 63 962 63 961 64 960 65 959 67 958 67 959 65 960 65 962 64 959 67 956 69 956 70 956 70 957 69 955 71 951 75 945 81 943 82 945 81 946 80 944 82 939 87 933 93 931 95 933 92 934 91 934 92 933 93 933 92 933 92 933 93 932 93 932 94 934 91 936 90 936 90 942 83 947 79 949 75 961 64 970 55 973 52 975 49 979 46 980 44 983 42 985 39 988 37 990 34 994 31 996 28 1000 23 1006 16 1013 10'],
#       dtype=object)

# %%
plt.imshow(img)

# %%
plt.imshow(mask)

# %%
mask_csv[mask_csv['ImageId'] == target_id][' EncodedPixels'].iloc[0]
# Out:
# ' 503035 2 1022 5 1016 9 1013 11 1012 12 1010 14 1009 15 1008 17 1007 17 1006 18 1005 19 1004 20 1004 20 1003 21 1002 22 1002 21 1002 22 1002 22 1002 22 1001 23 1001 22 1001 23 1001 22 1001 23 1001 22 1001 22 1002 22 1002 21 1002 22 1002 21 1002 21 1003 20 1003 20 1003 20 1004 19 1004 18 1005 18 1005 18 1004 18 1005 18 1005 18 1004 20 1003 20 1003 20 1004 19 1004 20 1003 20 1004 19 1005 19 1005 18 1005 19 1005 18 1006 18 1006 18 1006 18 1006 17 1007 17 1008 16 1008 16 1008 16 1008 16 1008 16 1009 16 1008 16 1008 16 1008 16 1008 16 1009 15 1009 15 1010 14 1010 14 1011 13 1011 13 1012 12 1012 12 1012 12 1013 11 1013 12 1013 11 1013 11 1013 11 1014 10 1014 10 1015 9 1015 9 1016 8 1016 8 1017 7 1017 7 1017 7 1018 6 1018 6 1019 5 1019 5 1020 4 1021 3 1022 2'

# %%
len(mask_csv)
# Out:
# 11582

# %%
mask_csv['ImageId'].nunique()
# Out:
# 10675

# %%
np.unique(mask)
# Out:
# array([  0., 255.])

# %%
mask[mask==255] = 1

# %%
np.unique(mask)
# Out:
# array([0., 1.])

# %%
mask = np.array(mask, dtype=np.uint8)

# %%
np.unique(mask)
# Out:
# array([0, 1], dtype=uint8)

# %%
import data_prep
a = data_prep.run_save_train()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 164.37it/s]

# %%
pd.read_csv('/data/pneumo/train/meta.csv')
# Out:
#    age body_part  class  height                                    id  \
# 0   24     CHEST      0    1024  0c6d6765-1866-44a3-aaa6-8dad35fc3f16
# 1   49     CHEST      0    1024  164db948-0b0e-4c65-a95c-7d228e7fdb34
# 2   64     CHEST      0    1024  d9251d05-4363-44c8-a7b4-69c8960aae62
# 3   60     CHEST      0    1024  417855ff-3d9b-4b41-bc19-b438f7b38d71
# 4   51     CHEST      0    1024  727b7115-0812-45c9-96a6-31be1a7f5d7b
# 5   58     CHEST      1    1024  d3c747da-7700-4842-9f66-7dc107287018
# 6   62     CHEST      0    1024  88245df4-d9fd-4a84-9ecf-ce8af4b90cb5
# 7   62     CHEST      0    1024  34365268-70b8-4405-8034-8f53cbeaeb55
# 8   78     CHEST      0    1024  ff143b17-eeb6-4f4c-8a68-903605b3c888
# 9   40     CHEST      0    1024  f193a755-27a2-4d75-a98a-120ed510d7b0
#
#   modality                                  name  \
# 0       CR  0c6d6765-1866-44a3-aaa6-8dad35fc3f16
# 1       CR  164db948-0b0e-4c65-a95c-7d228e7fdb34
# 2       CR  d9251d05-4363-44c8-a7b4-69c8960aae62
# 3       CR  417855ff-3d9b-4b41-bc19-b438f7b38d71
# 4       CR  727b7115-0812-45c9-96a6-31be1a7f5d7b
# 5       CR  d3c747da-7700-4842-9f66-7dc107287018
# 6       CR  88245df4-d9fd-4a84-9ecf-ce8af4b90cb5
# 7       CR  34365268-70b8-4405-8034-8f53cbeaeb55
# 8       CR  ff143b17-eeb6-4f4c-8a68-903605b3c888
# 9       CR  f193a755-27a2-4d75-a98a-120ed510d7b0
#
#                                                 path  \
# 0  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 1  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 2  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 3  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 4  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 5  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 6  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 7  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 8  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 9  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
#
#                                     pixel_spacing sex  \
# 0                              ['0.139', '0.139']   F
# 1  ['0.14300000000000002', '0.14300000000000002']   F
# 2                              ['0.139', '0.139']   M
# 3  ['0.14300000000000002', '0.14300000000000002']   M
# 4                              ['0.139', '0.139']   M
# 5                              ['0.139', '0.139']   M
# 6  ['0.14300000000000002', '0.14300000000000002']   F
# 7                              ['0.168', '0.168']   F
# 8                              ['0.168', '0.168']   F
# 9                              ['0.139', '0.139']   M
#
#                 storage_type view  width
# 0  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 1  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 2  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 3  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 4  1.2.840.10008.5.1.4.1.1.7   AP   1024
# 5  1.2.840.10008.5.1.4.1.1.7   AP   1024
# 6  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 7  1.2.840.10008.5.1.4.1.1.7   PA   1024
# 8  1.2.840.10008.5.1.4.1.1.7   AP   1024
# 9  1.2.840.10008.5.1.4.1.1.7   AP   1024

# %%
meta_df
# Out:
#   age body_part  class  height                                    id modality  \
# 0  24     CHEST      0    1024  0c6d6765-1866-44a3-aaa6-8dad35fc3f16       CR
# 1  49     CHEST      0    1024  164db948-0b0e-4c65-a95c-7d228e7fdb34       CR
# 2  64     CHEST      0    1024  d9251d05-4363-44c8-a7b4-69c8960aae62       CR
# 3  60     CHEST      0    1024  417855ff-3d9b-4b41-bc19-b438f7b38d71       CR
# 4  51     CHEST      0    1024  727b7115-0812-45c9-96a6-31be1a7f5d7b       CR
# 5  58     CHEST      1    1024  d3c747da-7700-4842-9f66-7dc107287018       CR
# 6  62     CHEST      0    1024  88245df4-d9fd-4a84-9ecf-ce8af4b90cb5       CR
# 7  62     CHEST      0    1024  34365268-70b8-4405-8034-8f53cbeaeb55       CR
# 8  78     CHEST      0    1024  ff143b17-eeb6-4f4c-8a68-903605b3c888       CR
# 9  40     CHEST      0    1024  f193a755-27a2-4d75-a98a-120ed510d7b0       CR
#
#                                    name  \
# 0  0c6d6765-1866-44a3-aaa6-8dad35fc3f16
# 1  164db948-0b0e-4c65-a95c-7d228e7fdb34
# 2  d9251d05-4363-44c8-a7b4-69c8960aae62
# 3  417855ff-3d9b-4b41-bc19-b438f7b38d71
# 4  727b7115-0812-45c9-96a6-31be1a7f5d7b
# 5  d3c747da-7700-4842-9f66-7dc107287018
# 6  88245df4-d9fd-4a84-9ecf-ce8af4b90cb5
# 7  34365268-70b8-4405-8034-8f53cbeaeb55
# 8  ff143b17-eeb6-4f4c-8a68-903605b3c888
# 9  f193a755-27a2-4d75-a98a-120ed510d7b0
#
#                                                 path  \
# 0  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 1  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 2  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 3  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 4  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 5  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 6  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 7  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 8  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
# 9  /data/pneumo/train/1.2.276.0.7230010.3.1.4.832...
#
#                                 pixel_spacing sex               storage_type  \
# 0                              [0.139, 0.139]   F  1.2.840.10008.5.1.4.1.1.7
# 1  [0.14300000000000002, 0.14300000000000002]   F  1.2.840.10008.5.1.4.1.1.7
# 2                              [0.139, 0.139]   M  1.2.840.10008.5.1.4.1.1.7
# 3  [0.14300000000000002, 0.14300000000000002]   M  1.2.840.10008.5.1.4.1.1.7
# 4                              [0.139, 0.139]   M  1.2.840.10008.5.1.4.1.1.7
# 5                              [0.139, 0.139]   M  1.2.840.10008.5.1.4.1.1.7
# 6  [0.14300000000000002, 0.14300000000000002]   F  1.2.840.10008.5.1.4.1.1.7
# 7                              [0.168, 0.168]   F  1.2.840.10008.5.1.4.1.1.7
# 8                              [0.168, 0.168]   F  1.2.840.10008.5.1.4.1.1.7
# 9                              [0.139, 0.139]   M  1.2.840.10008.5.1.4.1.1.7
#
#   view  width
# 0   PA   1024
# 1   PA   1024
# 2   PA   1024
# 3   PA   1024
# 4   AP   1024
# 5   AP   1024
# 6   PA   1024
# 7   PA   1024
# 8   AP   1024
# 9   AP   1024

# %%
save_numpy_list = glob('/data/pneumo/train/*')

# %%
# target_path = '/data/pneumo/train/1.2.276.0.7230010.3.1.4.8323329.4580.1517875183.601524.npy'
target_path = save_numpy_list[0]

# %%
data = np.load(target_path)[()]

# %%
plt.imshow(data['img'], cmap='gray')

# %%
im = data['img']

# %%
im.shape
# Out:
# (1024, 1024)

# %%
import cv2
im_resize = cv2.resize(im, (256, 256))

# %%
plt.imshow(im_resize, cmap='gray')

# %%
# mask = data['mask']
mask_resize = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)

# %%
np.unique(mask_resize)
# Out:
# array([  0., 255.])

# %%
rle = mask_csv[mask_csv['ImageId'] == '1.2.276.0.7230010.3.1.4.8323329.4580.1517875183.601524'][' EncodedPixels']
# Out:
# [autoreload of data_prep failed: Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/anaconda3/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/opt/anaconda3/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/opt/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/yusuke/work/siim_pneumo/data_prep.py", line 38
#     meta_df =
#              ^
# SyntaxError: invalid syntax
# ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-00229fdf38b2> in <module>
# ----> 1 rle = mask_csv[mask_csv['ImageId'] == '1.2.276.0.7230010.3.1.4.8323329.4580.1517875183.601524'][' EncodedPixels']
#
# NameError: name 'mask_csv' is not defined

# %%
plt.imshow(rle2mask(rle.iloc[0], 1024, 1024))

# %%
plt.imshow(rle2mask(rle.iloc[1], 1024, 1024))

# %%
a = data_prep.make_fold_df()

# %%
a[a['fold']=='5']['class'].value_counts()
# Out:
# 0    1659
# 1     476
# Name: class, dtype: int64

# %%
import data_generator
datagenerator = data_generator.DataGenerator(aug=False)
train_gen = datagenerator.generate(train=True)
val_gen = datagenerator.generate(train=False)

image_batch, mask_batch = next(train_gen)

# %%
import utils
utils.vis_slices(image_batch, mask_batch)

# %%
path_list = glob('/data/pneumo/fold/1/*.npy')

# %%
target = path_list[12]
data = np.load(target)[()]
img = data['img']
mask = data['mask']

# %%
plt.imshow(mask)

# %%
# plt.imshow(img)

# %%
plt.imshow(mask_batch[2], cmap='gray')

# %%
train_gen = data_generator.DataGenerator(mode='train')
val_gen = data_generator.DataGenerator(mode='val')

image_batch, mask_batch = next(train_gen)

# %%
a_list
# Out:
# [{'a': 1, 'b': 2, 'c': 3}]
