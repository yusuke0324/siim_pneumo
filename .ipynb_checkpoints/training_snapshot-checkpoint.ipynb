# %%
# %load_ext autoreload
# %autoreload 2
import sys
import matplotlib.pyplot as plt
import nibabel as nib
import utils, data_generator, train_util, models, loss_util
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.ndimage
from keras.optimizers import Adam
from keras.models import load_model
from keras.layers import Input
import os
from keras.models import Model
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import warnings
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,OneOf,
    ToFloat, ShiftScaleRotate,GridDistortion, ElasticTransform, JpegCompression, HueSaturationValue,
    RGBShift, RandomBrightness, RandomContrast, Blur, MotionBlur, MedianBlur, GaussNoise,CenterCrop,
    IAAAdditiveGaussianNoise,GaussNoise,OpticalDistortion,RandomSizedCrop
)
    
if not sys.warnoptions:
    warnings.simplefilter("ignore")
# Out:
# Using TensorFlow backend.

# %%
fold = '1'
output_ch = 1
input_shape = (256, 256, 3)
# input_shape = (512, 512, 3)
target_shape = input_shape[:2]
img_ch = input_shape[-1]
# AUGMENTATIONS = Compose([
# #     HorizontalFlip(p=0.5),
#     OneOf([
#         RandomContrast(),
#         RandomGamma(),
#         RandomBrightness(),
#          ], p=0.3),
#     OneOf([
#         ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
#         GridDistortion(),
#         OpticalDistortion(distort_limit=2, shift_limit=0.5),
#         ], p=0.3),
#     RandomSizedCrop(min_max_height=(624, 1024), height=1024, width=1024,p=0.25),

#     ToFloat(max_value=1)
# ],p=1)

AUGMENTATIONS = Compose([
#     HorizontalFlip(p=0.5),
    OneOf([
        RandomContrast(),
        RandomGamma(),
        RandomBrightness(),
         ], p=0.3),
    OneOf([
#         ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
#         GridDistortion(),
#         OpticalDistortion(distort_limit=2, shift_limit=0.5),
        RandomSizedCrop(min_max_height=(624, 1024), height=1024, width=1024,p=0.25),
        ShiftScaleRotate(rotate_limit=10),
        ], p=0.5),
    ToFloat(max_value=1)
],p=1)
maxrotate=10
# batch_size=16 
batch_size=4
generator = data_generator.DataGenerator(batch_size=batch_size,
                                             img_ch=img_ch,
                                             data_path='/data/pneumo/fold/[!'+fold+']/',
                                             target_shape=target_shape,
                                             output_ch=output_ch,
                                             aug=AUGMENTATIONS)
train_gen, val_gen = generator.get_train_val_gens()
# train_gen = datagenerator.generate(train=True)
# val_gen = datagenerator.generate(train=False)
zero_weight=1
one_weight=1

# %%
v, m = train_gen.__getitem__(0)
print(v.shape)
print(m.shape)
if img_ch == 3:
    v = v[:, :, :, 0]
# v = np.squeeze(v)
# m = np.argmax(m, axis=-1)
utils.vis_slices(v, m)
# Out:
# (4, 256, 256, 3)
# (4, 256, 256, 1)

# %%
# model= models.unet(img_shape=input_shape, out_ch=output_ch, start_ch=16, depth=5) 
model = models.UEfficientNet(input_shape, dropout_rate=0.5)
load=False
#++++++++++++++++++++ LOAD MODEL++++++++++++++++++++++++++++++
if load:
    custom_objects = {
                    'weighted_binary_crossentropy':loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
               'dice_coef':loss_util.create_dice_coef(),
               'dice_coef_flat':loss_util.dice_coef_flat,
               'bce_dice_loss':loss_util.bce_dice_loss,
               'dice_loss_flat':loss_util.dice_loss_flat,}
    model_path = '/data/pneumo_log/val_1//2019_0808_0447/best_weights.hdf5'
    loaded_model = load_model(model_path, custom_objects=custom_objects)
    if input_shape[0] != loaded_model.layers[0].input_shape[1]:
        model = models.UEfficientNet(input_shape, dropout_rate=0.5)
    #     new_input_l = Input((256, 256, 3))
        # try _layes instead of layers https://github.com/tensorflow/tensorflow/issues/22479
        loaded_model._layers.pop(0) # pop up doesn't support functional API? https://github.com/keras-team/keras/issues/8772
    #     new_out = loaded_model(new_input_l)
    #     model = Model(new_input_l, new_out)
        # set weights to avoid getting error in saving. https://github.com/keras-team/keras/issues/8772
        model.set_weights(loaded_model.get_weights())
    #     model = new_model

        # not try yet: https://datascience.stackexchange.com/questions/21734/keras-transfer-learning-changing-input-tensor-shape
    #     for new_layer, layer in zip(model.layers[1:], loaded_model.layers[1:]):
    #         print(layer)
    #         new_layer.set_weights(layer.get_weights())
    #+++++++++++++++++++++++++++++++++++++++++++++++++++++++
    else:
        model = loaded_model
    # loss = loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight)
loss = loss_util.bce_dice_loss

optimizer = Adam(lr=0.001)
steps_per_epoch = len(train_gen.data_paths) // train_gen.batch_size
validation_steps = len(val_gen.data_paths) // val_gen.batch_size
log_dir = '/data/pneumo_log/' +'val_'+fold+'/'

metrics = [
           loss,
           loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
           loss_util.create_dice_coef(),
           loss_util.dice_coef_flat,
           loss_util.bce_dice_loss,
           loss_util.dice_loss_flat,
           loss_util.my_dice_metric
          ]
epochs = 200
nb_snapshots=4
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/function.py:986: calling Graph.create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.

# %%
# model.summary()

# %%
train_util.train(model,
             train_gen,
             val_gen,
             optimizer=optimizer,
             loss=loss,
             metrics=metrics,
             lr_mode='cosine',
             validation_steps=validation_steps,
             steps_per_epoch=steps_per_epoch,
             log_dir=log_dir,
             epochs=epochs,
             check_point_monitor='val_my_dice_metric',
             check_point_mode='max',
             nb_snapshots=nb_snapshots,
             init_lr=1e-2)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 48) 1296        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# swish_1 (Swish)                 (None, 128, 128, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 128, 128, 48) 432         swish_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 48) 192         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# swish_2 (Swish)                 (None, 128, 128, 48) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1, 1, 48)     0           swish_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 12)     588         lambda_1[0][0]
# __________________________________________________________________________________________________
# swish_3 (Swish)                 (None, 1, 1, 12)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 1, 1, 48)     624         swish_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 48)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 128, 128, 48) 0           activation_1[0][0]
#                                                                  swish_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 24) 1152        multiply_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 24) 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 128, 128, 24) 216         batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 24) 96          depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# swish_4 (Swish)                 (None, 128, 128, 24) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1, 1, 24)     0           swish_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 1, 1, 6)      150         lambda_2[0][0]
# __________________________________________________________________________________________________
# swish_5 (Swish)                 (None, 1, 1, 6)      0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 24)     168         swish_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 1, 24)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 128, 128, 24) 0           activation_2[0][0]
#                                                                  swish_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 24) 576         multiply_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 24) 96          conv2d_7[0][0]
# __________________________________________________________________________________________________
# drop_connect_1 (DropConnect)    (None, 128, 128, 24) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 24) 0           drop_connect_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 144 3456        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 144 576         conv2d_8[0][0]
# __________________________________________________________________________________________________
# swish_6 (Swish)                 (None, 128, 128, 144 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 64, 64, 144)  1296        swish_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 144)  576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# swish_7 (Swish)                 (None, 64, 64, 144)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 1, 144)    0           swish_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 1, 1, 6)      870         lambda_3[0][0]
# __________________________________________________________________________________________________
# swish_8 (Swish)                 (None, 1, 1, 6)      0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1, 144)    1008        swish_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1, 1, 144)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 64, 64, 144)  0           activation_3[0][0]
#                                                                  swish_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 32)   4608        multiply_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 32)   128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 192)  6144        batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 192)  768         conv2d_12[0][0]
# __________________________________________________________________________________________________
# swish_9 (Swish)                 (None, 64, 64, 192)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 64, 64, 192)  1728        swish_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 192)  768         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# swish_10 (Swish)                (None, 64, 64, 192)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 1, 1, 192)    0           swish_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 1, 1, 8)      1544        lambda_4[0][0]
# __________________________________________________________________________________________________
# swish_11 (Swish)                (None, 1, 1, 8)      0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 192)    1728        swish_11[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1, 1, 192)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 64, 64, 192)  0           activation_4[0][0]
#                                                                  swish_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 32)   6144        multiply_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# drop_connect_2 (DropConnect)    (None, 64, 64, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           drop_connect_2[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 192)  6144        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 192)  768         conv2d_16[0][0]
# __________________________________________________________________________________________________
# swish_12 (Swish)                (None, 64, 64, 192)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 64, 64, 192)  1728        swish_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 192)  768         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# swish_13 (Swish)                (None, 64, 64, 192)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 1, 192)    0           swish_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 1, 1, 8)      1544        lambda_5[0][0]
# __________________________________________________________________________________________________
# swish_14 (Swish)                (None, 1, 1, 8)      0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 1, 1, 192)    1728        swish_14[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1, 1, 192)    0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 64, 64, 192)  0           activation_5[0][0]
#                                                                  swish_13[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 32)   6144        multiply_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# drop_connect_3 (DropConnect)    (None, 64, 64, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 32)   0           drop_connect_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 192)  6144        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 192)  768         conv2d_20[0][0]
# __________________________________________________________________________________________________
# swish_15 (Swish)                (None, 64, 64, 192)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 64, 64, 192)  1728        swish_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 192)  768         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# swish_16 (Swish)                (None, 64, 64, 192)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 1, 192)    0           swish_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 1, 1, 8)      1544        lambda_6[0][0]
# __________________________________________________________________________________________________
# swish_17 (Swish)                (None, 1, 1, 8)      0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 1, 1, 192)    1728        swish_17[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1, 1, 192)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 64, 64, 192)  0           activation_6[0][0]
#                                                                  swish_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   6144        multiply_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# drop_connect_4 (DropConnect)    (None, 64, 64, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 32)   0           drop_connect_4[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 192)  6144        add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 192)  768         conv2d_24[0][0]
# __________________________________________________________________________________________________
# swish_18 (Swish)                (None, 64, 64, 192)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 32, 32, 192)  4800        swish_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 192)  768         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# swish_19 (Swish)                (None, 32, 32, 192)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1, 1, 192)    0           swish_19[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 1, 1, 8)      1544        lambda_7[0][0]
# __________________________________________________________________________________________________
# swish_20 (Swish)                (None, 1, 1, 8)      0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 1, 1, 192)    1728        swish_20[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1, 1, 192)    0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 32, 32, 192)  0           activation_7[0][0]
#                                                                  swish_19[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 56)   10752       multiply_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 56)   224         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 336)  18816       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 336)  1344        conv2d_28[0][0]
# __________________________________________________________________________________________________
# swish_21 (Swish)                (None, 32, 32, 336)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 32, 32, 336)  8400        swish_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 336)  1344        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# swish_22 (Swish)                (None, 32, 32, 336)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1, 1, 336)    0           swish_22[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 1, 1, 14)     4718        lambda_8[0][0]
# __________________________________________________________________________________________________
# swish_23 (Swish)                (None, 1, 1, 14)     0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 1, 1, 336)    5040        swish_23[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1, 1, 336)    0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 32, 32, 336)  0           activation_8[0][0]
#                                                                  swish_22[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 56)   18816       multiply_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 56)   224         conv2d_31[0][0]
# __________________________________________________________________________________________________
# drop_connect_5 (DropConnect)    (None, 32, 32, 56)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 56)   0           drop_connect_5[0][0]
#                                                                  batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 336)  18816       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 336)  1344        conv2d_32[0][0]
# __________________________________________________________________________________________________
# swish_24 (Swish)                (None, 32, 32, 336)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 32, 32, 336)  8400        swish_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 336)  1344        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# swish_25 (Swish)                (None, 32, 32, 336)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1, 1, 336)    0           swish_25[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1, 1, 14)     4718        lambda_9[0][0]
# __________________________________________________________________________________________________
# swish_26 (Swish)                (None, 1, 1, 14)     0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1, 1, 336)    5040        swish_26[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1, 1, 336)    0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 32, 32, 336)  0           activation_9[0][0]
#                                                                  swish_25[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 56)   18816       multiply_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 56)   224         conv2d_35[0][0]
# __________________________________________________________________________________________________
# drop_connect_6 (DropConnect)    (None, 32, 32, 56)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 56)   0           drop_connect_6[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 336)  18816       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 336)  1344        conv2d_36[0][0]
# __________________________________________________________________________________________________
# swish_27 (Swish)                (None, 32, 32, 336)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 32, 32, 336)  8400        swish_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 336)  1344        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# swish_28 (Swish)                (None, 32, 32, 336)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 1, 1, 336)    0           swish_28[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 1, 1, 14)     4718        lambda_10[0][0]
# __________________________________________________________________________________________________
# swish_29 (Swish)                (None, 1, 1, 14)     0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 1, 1, 336)    5040        swish_29[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1, 1, 336)    0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 32, 32, 336)  0           activation_10[0][0]
#                                                                  swish_28[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 56)   18816       multiply_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 56)   224         conv2d_39[0][0]
# __________________________________________________________________________________________________
# drop_connect_7 (DropConnect)    (None, 32, 32, 56)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 56)   0           drop_connect_7[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 336)  18816       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 336)  1344        conv2d_40[0][0]
# __________________________________________________________________________________________________
# swish_30 (Swish)                (None, 32, 32, 336)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 16, 16, 336)  3024        swish_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 336)  1344        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# swish_31 (Swish)                (None, 16, 16, 336)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1, 1, 336)    0           swish_31[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 1, 1, 14)     4718        lambda_11[0][0]
# __________________________________________________________________________________________________
# swish_32 (Swish)                (None, 1, 1, 14)     0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 1, 1, 336)    5040        swish_32[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1, 1, 336)    0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 16, 16, 336)  0           activation_11[0][0]
#                                                                  swish_31[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 112)  37632       multiply_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 112)  448         conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 672)  75264       batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 672)  2688        conv2d_44[0][0]
# __________________________________________________________________________________________________
# swish_33 (Swish)                (None, 16, 16, 672)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 16, 16, 672)  6048        swish_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 672)  2688        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# swish_34 (Swish)                (None, 16, 16, 672)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1, 1, 672)    0           swish_34[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 1, 1, 28)     18844       lambda_12[0][0]
# __________________________________________________________________________________________________
# swish_35 (Swish)                (None, 1, 1, 28)     0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 1, 1, 672)    19488       swish_35[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 672)    0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 16, 16, 672)  0           activation_12[0][0]
#                                                                  swish_34[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 112)  75264       multiply_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 112)  448         conv2d_47[0][0]
# __________________________________________________________________________________________________
# drop_connect_8 (DropConnect)    (None, 16, 16, 112)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 112)  0           drop_connect_8[0][0]
#                                                                  batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 672)  75264       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 672)  2688        conv2d_48[0][0]
# __________________________________________________________________________________________________
# swish_36 (Swish)                (None, 16, 16, 672)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 16, 16, 672)  6048        swish_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 672)  2688        depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# swish_37 (Swish)                (None, 16, 16, 672)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 1, 1, 672)    0           swish_37[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 1, 1, 28)     18844       lambda_13[0][0]
# __________________________________________________________________________________________________
# swish_38 (Swish)                (None, 1, 1, 28)     0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 1, 1, 672)    19488       swish_38[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 1, 1, 672)    0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 16, 16, 672)  0           activation_13[0][0]
#                                                                  swish_37[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 112)  75264       multiply_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16, 16, 112)  448         conv2d_51[0][0]
# __________________________________________________________________________________________________
# drop_connect_9 (DropConnect)    (None, 16, 16, 112)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 112)  0           drop_connect_9[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 672)  75264       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 16, 16, 672)  2688        conv2d_52[0][0]
# __________________________________________________________________________________________________
# swish_39 (Swish)                (None, 16, 16, 672)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 16, 16, 672)  6048        swish_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 16, 16, 672)  2688        depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# swish_40 (Swish)                (None, 16, 16, 672)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1, 1, 672)    0           swish_40[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 1, 1, 28)     18844       lambda_14[0][0]
# __________________________________________________________________________________________________
# swish_41 (Swish)                (None, 1, 1, 28)     0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 1, 1, 672)    19488       swish_41[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1, 1, 672)    0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 16, 16, 672)  0           activation_14[0][0]
#                                                                  swish_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 112)  75264       multiply_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 112)  448         conv2d_55[0][0]
# __________________________________________________________________________________________________
# drop_connect_10 (DropConnect)   (None, 16, 16, 112)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 112)  0           drop_connect_10[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 672)  75264       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 672)  2688        conv2d_56[0][0]
# __________________________________________________________________________________________________
# swish_42 (Swish)                (None, 16, 16, 672)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 16, 16, 672)  6048        swish_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 672)  2688        depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# swish_43 (Swish)                (None, 16, 16, 672)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1, 1, 672)    0           swish_43[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 1, 1, 28)     18844       lambda_15[0][0]
# __________________________________________________________________________________________________
# swish_44 (Swish)                (None, 1, 1, 28)     0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 1, 1, 672)    19488       swish_44[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 1, 672)    0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 16, 16, 672)  0           activation_15[0][0]
#                                                                  swish_43[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 16, 16, 112)  75264       multiply_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 112)  448         conv2d_59[0][0]
# __________________________________________________________________________________________________
# ...
#
# Epoch 00113: val_my_dice_metric did not improve from 0.00000
# Epoch 114/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0178 - bce_dice_loss: 1.0178 - weighted_binary_crossentropy: 0.0201 - dice_coef: 0.0026 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.0178 - dice_loss_flat: 0.9977 - my_dice_metric: 0.0000e+00 - val_loss: 1.0205 - val_bce_dice_loss: 1.0205 - val_weighted_binary_crossentropy: 0.0232 - val_dice_coef: 0.0045 - val_dice_coef_flat: nan - val_bce_dice_loss_1: 1.0205 - val_dice_loss_flat: 0.9973 - val_my_dice_metric: 0.7383
# Finished epoch: 113
# {'val_loss': 1.0204545438569477, 'val_bce_dice_loss': 1.0204545416182755, 'val_weighted_binary_crossentropy': 0.023184759167412146, 'val_dice_coef': 0.004519416985622314, 'val_dice_coef_flat': nan, 'val_bce_dice_loss_1': 1.0204545416182755, 'val_dice_loss_flat': 0.997269782661832, 'val_my_dice_metric': 0.7382629107981221, 'loss': 1.0178372859954834, 'bce_dice_loss': 1.0178372263908386, 'weighted_binary_crossentropy': 0.020121742971241474, 'dice_coef': 0.0026462305686436594, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.0178372263908386, 'dice_loss_flat': 0.9977155029773712, 'my_dice_metric': 0.0}
#
# Epoch 00114: val_my_dice_metric did not improve from 0.00000
# Epoch 115/200
# 2/2 [==============================] - 13s 6s/step - loss: 1.0585 - bce_dice_loss: 1.0585 - weighted_binary_crossentropy: 0.0678 - dice_coef: 0.0093 - dice_coef_flat: 3.8088e-04 - bce_dice_loss_1: 1.0585 - dice_loss_flat: 0.9906 - my_dice_metric: 2.6274e-04 - val_loss: 1.0249 - val_bce_dice_loss: 1.0249 - val_weighted_binary_crossentropy: 0.0271 - val_dice_coef: 0.0031 - val_dice_coef_flat: 1.7740e-05 - val_bce_dice_loss_1: 1.0249 - val_dice_loss_flat: 0.9977 - val_my_dice_metric: 0.1714
# Finished epoch: 114
# {'val_loss': 1.0248797667418288, 'val_bce_dice_loss': 1.0248797639434886, 'val_weighted_binary_crossentropy': 0.027138578860710066, 'val_dice_coef': 0.0031030546308674373, 'val_dice_coef_flat': 1.7740269641920994e-05, 'val_bce_dice_loss_1': 1.0248797639434886, 'val_dice_loss_flat': 0.997741184044332, 'val_my_dice_metric': 0.17136614938499775, 'loss': 1.058476984500885, 'bce_dice_loss': 1.0584770441055298, 'weighted_binary_crossentropy': 0.06784768495708704, 'dice_coef': 0.009326680563390255, 'dice_coef_flat': 0.00038087982102297246, 'bce_dice_loss_1': 1.0584770441055298, 'dice_loss_flat': 0.9906292855739594, 'my_dice_metric': 0.0002627430373095113}
#
# Epoch 00115: val_my_dice_metric did not improve from 0.00000
# Epoch 116/200
# 1/2 [==============>...............] - ETA: 0s - loss: 1.0167 - bce_dice_loss: 1.0167 - weighted_binary_crossentropy: 0.0213 - dice_coef: 0.0043 - dice_coef_flat: 0.0046 - bce_dice_loss_1: 1.0167 - dice_loss_flat: 0.9954 - my_dice_metric: 0.002Finished epoch: 114
# {'val_loss': 1.0248797667418288, 'val_bce_dice_loss': 1.0248797639434886, 'val_weighted_binary_crossentropy': 0.027138578860710066, 'val_dice_coef': 0.0031030546308674373, 'val_dice_coef_flat': 1.7740269641920994e-05, 'val_bce_dice_loss_1': 1.0248797639434886, 'val_dice_loss_flat': 0.997741184044332, 'val_my_dice_metric': 0.17136614938499775, 'loss': 1.058476984500885, 'bce_dice_loss': 1.0584770441055298, 'weighted_binary_crossentropy': 0.06784768495708704, 'dice_coef': 0.009326680563390255, 'dice_coef_flat': 0.00038087982102297246, 'bce_dice_loss_1': 1.0584770441055298, 'dice_loss_flat': 0.9906292855739594, 'my_dice_metric': 0.0002627430373095113}
# 2/2 [==============================] - 12s 6s/step - loss: 1.0157 - bce_dice_loss: 1.0157 - weighted_binary_crossentropy: 0.0182 - dice_coef: 0.0028 - dice_coef_flat: 0.0023 - bce_dice_loss_1: 1.0157 - dice_loss_flat: 0.9974 - my_dice_metric: 0.0011 - val_loss: 1.3198 - val_bce_dice_loss: 1.3198 - val_weighted_binary_crossentropy: 0.3224 - val_dice_coef: 0.0023 - val_dice_coef_flat: 0.0022 - val_bce_dice_loss_1: 1.3198 - val_dice_loss_flat: 0.9974 - val_my_dice_metric: 0.0099
# Finished epoch: 115
# {'val_loss': 1.319771193002871, 'val_bce_dice_loss': 1.319771171175818, 'val_weighted_binary_crossentropy': 0.32235250968328666, 'val_dice_coef': 0.0022988599030128263, 'val_dice_coef_flat': 0.0021553248029170524, 'val_bce_dice_loss_1': 1.319771171175818, 'val_dice_loss_flat': 0.9974186521180919, 'val_my_dice_metric': 0.00985785451664153, 'loss': 1.01566743850708, 'bce_dice_loss': 1.01566743850708, 'weighted_binary_crossentropy': 0.01822051592171192, 'dice_coef': 0.002847180818207562, 'dice_coef_flat': 0.0023121386766433716, 'bce_dice_loss_1': 1.01566743850708, 'dice_loss_flat': 0.9974469244480133, 'my_dice_metric': 0.0010638297872340426}
#
# Epoch 00116: val_my_dice_metric did not improve from 0.00000
# Epoch 117/200
# 2/2 [==============================] - 11s 6s/step - loss: 1.0225 - bce_dice_loss: 1.0225 - weighted_binary_crossentropy: 0.0304 - dice_coef: 0.0056 - dice_coef_flat: 5.5249e-04 - bce_dice_loss_1: 1.0225 - dice_loss_flat: 0.9920 - my_dice_metric: 1.6656e-04 - val_loss: 2.0788 - val_bce_dice_loss: 2.0788 - val_weighted_binary_crossentropy: 1.0821 - val_dice_coef: 0.0029 - val_dice_coef_flat: 0.0030 - val_bce_dice_loss_1: 2.0788 - val_dice_loss_flat: 0.9967 - val_my_dice_metric: 0.0025
# Finished epoch: 116
# {'val_loss': 2.0788477703998907, 'val_bce_dice_loss': 2.078847889049512, 'val_weighted_binary_crossentropy': 1.082133109300909, 'val_dice_coef': 0.0028936854776671645, 'val_dice_coef_flat': 0.0029522942009785305, 'val_bce_dice_loss_1': 2.078847889049512, 'val_dice_loss_flat': 0.9967147237818006, 'val_my_dice_metric': 0.002456941123239621, 'loss': 1.0224624872207642, 'bce_dice_loss': 1.0224624872207642, 'weighted_binary_crossentropy': 0.030416546389460564, 'dice_coef': 0.005624642362818122, 'dice_coef_flat': 0.0005524861626327038, 'bce_dice_loss_1': 1.0224624872207642, 'dice_loss_flat': 0.9920458793640137, 'my_dice_metric': 0.00016655562958027982}
#
# Epoch 00117: val_my_dice_metric did not improve from 0.00000
# Epoch 118/200
# 2/2 [==============================] - 13s 7s/step - loss: 1.0334 - bce_dice_loss: 1.0334 - weighted_binary_crossentropy: 0.0447 - dice_coef: 0.0055 - dice_coef_flat: 8.4818e-04 - bce_dice_loss_1: 1.0334 - dice_loss_flat: 0.9886 - my_dice_metric: 2.3198e-04 - val_loss: 1.5294 - val_bce_dice_loss: 1.5294 - val_weighted_binary_crossentropy: 0.5326 - val_dice_coef: 0.0026 - val_dice_coef_flat: 0.0026 - val_bce_dice_loss_1: 1.5294 - val_dice_loss_flat: 0.9968 - val_my_dice_metric: 0.0054
# Finished epoch: 117
# {'val_loss': 1.52944196781642, 'val_bce_dice_loss': 1.5294419493473752, 'val_weighted_binary_crossentropy': 0.5326041824101282, 'val_dice_coef': 0.002590081135744006, 'val_dice_coef_flat': 0.0025979969554860583, 'val_bce_dice_loss_1': 1.5294419493473752, 'val_dice_loss_flat': 0.9968377407727667, 'val_my_dice_metric': 0.005376058032572151, 'loss': 1.03335303068161, 'bce_dice_loss': 1.03335303068161, 'weighted_binary_crossentropy': 0.04473772458732128, 'dice_coef': 0.005456153652630746, 'dice_coef_flat': 0.0008481764234602451, 'bce_dice_loss_1': 1.03335303068161, 'dice_loss_flat': 0.9886153042316437, 'my_dice_metric': 0.00023198267862666253}
#
# Epoch 00118: val_my_dice_metric did not improve from 0.00000
# Epoch 119/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0175 - bce_dice_loss: 1.0175 - weighted_binary_crossentropy: 0.0177 - dice_coef: 9.6437e-04 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.0175 - dice_loss_flat: 0.9998 - my_dice_metric: 0.0000e+00 - val_loss: 2.2634 - val_bce_dice_loss: 2.2634 - val_weighted_binary_crossentropy: 1.2672 - val_dice_coef: 0.0035 - val_dice_coef_flat: 0.0036 - val_bce_dice_loss_1: 2.2634 - val_dice_loss_flat: 0.9962 - val_my_dice_metric: 0.0067
# Finished epoch: 118
# {'val_loss': 2.2633846242662887, 'val_bce_dice_loss': 2.263384394802398, 'val_weighted_binary_crossentropy': 1.2672224430970742, 'val_dice_coef': 0.003481118425410164, 'val_dice_coef_flat': 0.0036041361292151347, 'val_bce_dice_loss_1': 2.263384394802398, 'val_dice_loss_flat': 0.9961619170059061, 'val_my_dice_metric': 0.006653885938827982, 'loss': 1.017467975616455, 'bce_dice_loss': 1.017467975616455, 'weighted_binary_crossentropy': 0.017707369290292263, 'dice_coef': 0.0009643678204156458, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.017467975616455, 'dice_loss_flat': 0.999760627746582, 'my_dice_metric': 0.0}
#
# Epoch 00119: val_my_dice_metric did not improve from 0.00000
# Epoch 120/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0466 - bce_dice_loss: 1.0466 - weighted_binary_crossentropy: 0.0537 - dice_coef: 0.0054 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.0466 - dice_loss_flat: 0.9929 - my_dice_metric: 0.0000e+00 - val_loss: 2.6243 - val_bce_dice_loss: 2.6243 - val_weighted_binary_crossentropy: 1.6299 - val_dice_coef: 0.0050 - val_dice_coef_flat: 0.0055 - val_bce_dice_loss_1: 2.6243 - val_dice_loss_flat: 0.9944 - val_my_dice_metric: 0.0049
# Finished epoch: 119
# {'val_loss': 2.62429193599683, 'val_bce_dice_loss': 2.6242914087895497, 'val_weighted_binary_crossentropy': 1.6298745534789394, 'val_dice_coef': 0.004996381626630304, 'val_dice_coef_flat': 0.00554862437958194, 'val_bce_dice_loss_1': 2.6242914087895497, 'val_dice_loss_flat': 0.9944168429979137, 'val_my_dice_metric': 0.0048627770416132116, 'loss': 1.0465624332427979, 'bce_dice_loss': 1.0465624332427979, 'weighted_binary_crossentropy': 0.053652022033929825, 'dice_coef': 0.005435182712972164, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.0465624332427979, 'dice_loss_flat': 0.9929104149341583, 'my_dice_metric': 0.0}
#
# Epoch 00120: val_my_dice_metric did not improve from 0.00000
# Epoch 121/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0224 - bce_dice_loss: 1.0224 - weighted_binary_crossentropy: 0.0310 - dice_coef: 0.0068 - dice_coef_flat: 0.0012 - bce_dice_loss_1: 1.0224 - dice_loss_flat: 0.9915 - my_dice_metric: 6.2657e-04 - val_loss: 2.0699 - val_bce_dice_loss: 2.0699 - val_weighted_binary_crossentropy: 1.0748 - val_dice_coef: 0.0041 - val_dice_coef_flat: 0.0048 - val_bce_dice_loss_1: 2.0699 - val_dice_loss_flat: 0.9952 - val_my_dice_metric: 0.0039
# Finished epoch: 120
# {'val_loss': 2.069913380582568, 'val_bce_dice_loss': 2.0699141137476817, 'val_weighted_binary_crossentropy': 1.0747597911548166, 'val_dice_coef': 0.004130194578789822, 'val_dice_coef_flat': 0.004781274869757925, 'val_bce_dice_loss_1': 2.0699141137476817, 'val_dice_loss_flat': 0.9951542571117061, 'val_my_dice_metric': 0.003929715160564214, 'loss': 1.022443175315857, 'bce_dice_loss': 1.022443175315857, 'weighted_binary_crossentropy': 0.03097510989755392, 'dice_coef': 0.006818067515268922, 'dice_coef_flat': 0.0011668611550703645, 'bce_dice_loss_1': 1.022443175315857, 'dice_loss_flat': 0.9914681613445282, 'my_dice_metric': 0.0006265664160401002}
#
# Epoch 00121: val_my_dice_metric did not improve from 0.00000
# Epoch 122/200
# 2/2 [==============================] - 13s 7s/step - loss: 1.0262 - bce_dice_loss: 1.0262 - weighted_binary_crossentropy: 0.0342 - dice_coef: 0.0059 - dice_coef_flat: 5.3648e-04 - bce_dice_loss_1: 1.0262 - dice_loss_flat: 0.9920 - my_dice_metric: 1.6319e-04 - val_loss: 1.7587 - val_bce_dice_loss: 1.7587 - val_weighted_binary_crossentropy: 0.7634 - val_dice_coef: 0.0041 - val_dice_coef_flat: 0.0046 - val_bce_dice_loss_1: 1.7587 - val_dice_loss_flat: 0.9953 - val_my_dice_metric: 0.0038
# Finished epoch: 121
# {'val_loss': 1.7586715613172648, 'val_bce_dice_loss': 1.7586725435346504, 'val_weighted_binary_crossentropy': 0.7633994631644146, 'val_dice_coef': 0.0040875541912134905, 'val_dice_coef_flat': 0.004644331143150476, 'val_bce_dice_loss_1': 1.7586725435346504, 'val_dice_loss_flat': 0.9952730197861721, 'val_my_dice_metric': 0.003845940474242399, 'loss': 1.0262445211410522, 'bce_dice_loss': 1.0262445211410522, 'weighted_binary_crossentropy': 0.034216007217764854, 'dice_coef': 0.00587265775538981, 'dice_coef_flat': 0.0005364806856960058, 'bce_dice_loss_1': 1.0262445211410522, 'dice_loss_flat': 0.9920285642147064, 'my_dice_metric': 0.00016318537859007833}
#
# Epoch 00122: val_my_dice_metric did not improve from 0.00000
# Epoch 123/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0495 - bce_dice_loss: 1.0495 - weighted_binary_crossentropy: 0.0647 - dice_coef: 0.0108 - dice_coef_flat: 0.0029 - bce_dice_loss_1: 1.0495 - dice_loss_flat: 0.9847 - my_dice_metric: 0.0013 - val_loss: 2.2718 - val_bce_dice_loss: 2.2718 - val_weighted_binary_crossentropy: 1.2770 - val_dice_coef: 0.0046 - val_dice_coef_flat: 0.0051 - val_bce_dice_loss_1: 2.2718 - val_dice_loss_flat: 0.9948 - val_my_dice_metric: 0.0045
# Finished epoch: 122
# {'val_loss': 2.2717812469867473, 'val_bce_dice_loss': 2.271779844458674, 'val_weighted_binary_crossentropy': 1.2769562811918662, 'val_dice_coef': 0.004594009128787791, 'val_dice_coef_flat': 0.0051442090581576205, 'val_bce_dice_loss_1': 2.271779844458674, 'val_dice_loss_flat': 0.9948235425590909, 'val_my_dice_metric': 0.004462979677429722, 'loss': 1.0494515895843506, 'bce_dice_loss': 1.0494515895843506, 'weighted_binary_crossentropy': 0.06470200046896935, 'dice_coef': 0.010845170123502612, 'dice_coef_flat': 0.002897137892432511, 'bce_dice_loss_1': 1.0494515895843506, 'dice_loss_flat': 0.9847495555877686, 'my_dice_metric': 0.0012566763612523453}
#
# Epoch 00123: val_my_dice_metric did not improve from 0.00000
# Epoch 124/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0186 - bce_dice_loss: 1.0186 - weighted_binary_crossentropy: 0.0224 - dice_coef: 0.0038 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.0186 - dice_loss_flat: 0.9962 - my_dice_metric: 0.0000e+00 - val_loss: 2.9392 - val_bce_dice_loss: 2.9392 - val_weighted_binary_crossentropy: 1.9439 - val_dice_coef: 0.0045 - val_dice_coef_flat: 0.0048 - val_bce_dice_loss_1: 2.9392 - val_dice_loss_flat: 0.9952 - val_my_dice_metric: 0.0044
# Finished epoch: 123
# {'val_loss': 2.9391611282814276, 'val_bce_dice_loss': 2.9391599171598193, 'val_weighted_binary_crossentropy': 1.9439477719051736, 'val_dice_coef': 0.004468239230478724, 'val_dice_coef_flat': 0.004752027821315681, 'val_bce_dice_loss_1': 2.9391599171598193, 'val_dice_loss_flat': 0.9952120103746512, 'val_my_dice_metric': 0.004367045165617304, 'loss': 1.0185856819152832, 'bce_dice_loss': 1.0185856819152832, 'weighted_binary_crossentropy': 0.022377523593604565, 'dice_coef': 0.0038182269781827927, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.0185856819152832, 'dice_loss_flat': 0.9962081909179688, 'my_dice_metric': 0.0}
#
# Epoch 00124: val_my_dice_metric did not improve from 0.00000
# Epoch 125/200
# 2/2 [==============================] - 12s 6s/step - loss: 1.0294 - bce_dice_loss: 1.0294 - weighted_binary_crossentropy: 0.0367 - dice_coef: 0.0062 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.0294 - dice_loss_flat: 0.9926 - my_dice_metric: 0.0000e+00 - val_loss: 2.0071 - val_bce_dice_loss: 2.0071 - val_weighted_binary_crossentropy: 1.0123 - val_dice_coef: 0.0046 - val_dice_coef_flat: 0.0051 - val_bce_dice_loss_1: 2.0071 - val_dice_loss_flat: 0.9948 - val_my_dice_metric: 0.0045
# Finished epoch: 124
# {'val_loss': 2.0071250815906434, 'val_bce_dice_loss': 2.007124380886275, 'val_weighted_binary_crossentropy': 1.0122748238379966, 'val_dice_coef': 0.004616693993363565, 'val_dice_coef_flat': 0.005123735156550811, 'val_bce_dice_loss_1': 2.007124380886275, 'val_dice_loss_flat': 0.9948495100361641, 'val_my_dice_metric': 0.004477263545472938, 'loss': 1.029397964477539, 'bce_dice_loss': 1.0293979048728943, 'weighted_binary_crossentropy': 0.03674928564578295, 'dice_coef': 0.006197644514031708, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.0293979048728943, 'dice_loss_flat': 0.9926486313343048, 'my_dice_metric': 0.0}
#
# Epoch 00125: val_my_dice_metric did not improve from 0.00000
# Epoch 126/200
# 1/2 [==============>...............] - ETA: 1s - loss: 1.0500 - bce_dice_loss: 1.0500 - weighted_binary_crossentropy: 0.0673 - dice_coef: 0.0084 - dice_coef_flat: 0.0021 - bce_dice_loss_1: 1.0500 - dice_loss_flat: 0.9826 - my_dice_metric: 5.7078e-04

# %%
model.get_config()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-557c9cec7497> in <module>
# ----> 1 model.get_config()
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in get_config(self)
#     853         for layer in self.layers:  # From the earliest layers on.
#     854             layer_class_name = layer.__class__.__name__
# --> 855             layer_config = layer.get_config()
#     856             filtered_inbound_nodes = []
#     857             for original_node_index, node in enumerate(layer._inbound_nodes):
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/engine/network.py in get_config(self)
#     908             if node_key not in self._network_nodes:
#     909                 continue
# --> 910             new_node_index = node_conversion_map[node_key]
#     911             tensor_index = self._input_coordinates[i][2]
#     912             model_inputs.append([layer.name, new_node_index, tensor_index])
#
# KeyError: 'input_3_ib-0'

# %% [markdown]
# ## See training results

# %%
# laod model
from keras.models import load_model
# model_path = '/data/kits_log/2019_0724_0242/best_weights.hdf5'
model_path = '/data/pneumo_log/val_1//2019_0805_0344/best_weights.hdf5'
custom_objects = {
                'weighted_binary_crossentropy':loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
           'dice_coef':loss_util.create_dice_coef(),
           'dice_coef_flat':loss_util.dice_coef_flat,
           'bce_dice_loss':loss_util.bce_dice_loss,
           'dice_loss_flat':loss_util.dice_loss_flat,}
model = load_model(model_path, custom_objects=custom_objects)

# %%
images, masks = val_gen.__getitem__(0)
pred = model.predict(images)
index = 10

i = np.squeeze(images[index])
m = np.squeeze(masks[index])
p = np.squeeze(pred[index])
print(np.unique(p))
# Out:
# [9.1127363e-11 1.2514501e-10 1.7214875e-10 ... 3.5596595e-03 3.6568183e-03
#  3.6711448e-03]

# %%
plt.imshow(m)

# %%
plt.imshow(p)

# %%
'/'.join(model_path.split('/')[:-2])
# Out:
# '/data/pneumo_log/val_1/'

# %%
m = np.expand_dims(m, axis=0)
p = np.expand_dims(p, axis=0)
m = np.expand_dims(m, axis=-1)
p = np.expand_dims(p, axis=-1)

# %%
import keras.backend as K
y_true = K.variable(m)
y_pred = K.variable(p)
# m = np.array(m, dtype=np.float32)
loss_flat = loss_util.dice_coef_flat(y_true, y_pred)
dice_coef = loss_util.create_dice_coef()
dice_value = dice_coef(y_true, y_pred)
loss = loss_util.bce_dice_loss(y_true, y_pred)

# %%
K.get_value(loss_flat)
# Out:
# nan

# %%
K.get_value(dice_value)
# Out:
# 0.60813135

# %%
plt.imshow(np.reshape(K.get_value(loss), (256, 256)))

# %%
import eval_util

# %%
m = np.squeeze(m)
p = np.squeeze(p)
thresh=0.01
eval_util.evaluation(m, p, thresh)
# Out:
# 1.0

# %%
np.unique(a)
# Out:
# array([1.])

# %%
# p = np.where(p>thresh, 1, 0)

# %%
plt.imshow(p)

# %%
a = np.greater(p_binary, 0)

# %%
a.sum()
# Out:
# 61169

# %%
import cv2
cv2.resize(t, (256, 256, 3))
