# %%
# %load_ext autoreload
# %autoreload 2
import sys
import matplotlib.pyplot as plt
import nibabel as nib
import utils, data_generator, train_util, models, loss_util
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.ndimage
from keras.optimizers import Adam
from keras.models import load_model
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
import warnings
    
if not sys.warnoptions:
    warnings.simplefilter("ignore")
# Out:
# Using TensorFlow backend.

# %%
fold = '1'
output_ch = 1
input_shape = (256, 256, 3)
target_shape = input_shape[:2]
img_ch = input_shape[-1]
aug=True
flip=False
maxshift=[0, 20, 20] # z, x, y
maxrotate=10
train_gen = data_generator.DataGenerator(batch_size=32,
                                             mode='train',
                                             img_ch=img_ch,
                                             data_path='/data/pneumo/fold/[!'+fold+']/',
                                             target_shape=target_shape,
                                             output_ch=output_ch,
                                             aug=aug, flip=flip,
                                             maxshift=maxshift, maxrotate=maxrotate)
val_gen = data_generator.DataGenerator(batch_size=32,
                                             mode='train',
                                             img_ch=img_ch,
                                             data_path='/data/pneumo/fold/[!'+fold+']/',
                                             target_shape=target_shape,
                                             output_ch=output_ch,
                                             aug=aug, flip=flip,
                                             maxshift=maxshift, maxrotate=maxrotate)
# train_gen = datagenerator.generate(train=True)
# val_gen = datagenerator.generate(train=False)
zero_weight=1
one_weight=1

# %%
v, m = train_gen.__getitem__(0)
# v = np.squeeze(v)
# m = np.argmax(m, axis=-1)
utils.vis_slices(v, m)

# %%
# model= models.unet(img_shape=input_shape, out_ch=output_ch, start_ch=16, depth=5) 
model = models.UEfficientNet(input_shape=(256, 256, 3), dropout_rate=0.5)
custom_objects = {
                  'weighted_binary_crossentropy': loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
                  'dice_coef': loss_util.create_dice_coef(),
                }

# model = load_model(model_path, custom_objects=custom_objects)

# loss = loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight)
loss = loss_util.bce_dice_loss

optimizer = Adam(lr=0.001)
steps_per_epoch = len(train_gen.data_paths) // train_gen.batch_size
validation_steps = len(val_gen.data_paths) // val_gen.batch_size
log_dir = '/data/pneumo_log/' +'val_'+fold+'/'

metrics = [
           loss,
           loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
           loss_util.create_dice_coef(),
           loss_util.dice_coef_flat,
           loss_util.bce_dice_loss,
           loss_util.dice_loss_flat,
          ]
epochs = 150
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/function.py:986: calling Graph.create_op (from tensorflow.python.framework.ops) with compute_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Shapes are always computed; don't use the compute_shapes as it has no effect.

# %%
train_util.train(model,
             train_gen,
             val_gen,
             optimizer=optimizer,
             loss=loss,
             metrics=metrics,
             lr_mode='cosine',
             validation_steps=validation_steps,
             steps_per_epoch=steps_per_epoch,
             log_dir=log_dir,
             epochs=epochs)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 256, 256, 16) 160         input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 256, 256, 16) 2320        conv2d_253[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 128, 128, 16) 0           conv2d_254[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 128, 128, 32) 4640        max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 128, 128, 32) 9248        conv2d_255[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 64, 64, 32)   0           conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 64, 64, 64)   18496       max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 64, 64, 64)   36928       conv2d_257[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 32, 32, 64)   0           conv2d_258[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 32, 32, 128)  73856       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 32, 32, 128)  147584      conv2d_259[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 16, 16, 128)  0           conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 16, 16, 256)  295168      max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_261[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 8, 8, 256)    0           conv2d_262[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 8, 8, 512)    1180160     max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 8, 8, 512)    0           conv2d_263[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 8, 8, 512)    2359808     dropout_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_46 (UpSampling2D) (None, 16, 16, 512)  0           conv2d_264[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 16, 16, 256)  524544      up_sampling2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 16, 16, 512)  0           conv2d_262[0][0]
#                                                                  conv2d_265[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 16, 16, 256)  1179904     concatenate_46[0][0]
# __________________________________________________________________________________________________
# conv2d_267 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_266[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_47 (UpSampling2D) (None, 32, 32, 256)  0           conv2d_267[0][0]
# __________________________________________________________________________________________________
# conv2d_268 (Conv2D)             (None, 32, 32, 128)  131200      up_sampling2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 32, 32, 256)  0           conv2d_260[0][0]
#                                                                  conv2d_268[0][0]
# __________________________________________________________________________________________________
# conv2d_269 (Conv2D)             (None, 32, 32, 128)  295040      concatenate_47[0][0]
# __________________________________________________________________________________________________
# conv2d_270 (Conv2D)             (None, 32, 32, 128)  147584      conv2d_269[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_48 (UpSampling2D) (None, 64, 64, 128)  0           conv2d_270[0][0]
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 64, 64, 64)   32832       up_sampling2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 64, 64, 128)  0           conv2d_258[0][0]
#                                                                  conv2d_271[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 64, 64, 64)   73792       concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 64, 64, 64)   36928       conv2d_272[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_49 (UpSampling2D) (None, 128, 128, 64) 0           conv2d_273[0][0]
# __________________________________________________________________________________________________
# conv2d_274 (Conv2D)             (None, 128, 128, 32) 8224        up_sampling2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 128, 128, 64) 0           conv2d_256[0][0]
#                                                                  conv2d_274[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 128, 128, 32) 18464       concatenate_49[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 128, 128, 32) 9248        conv2d_275[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_50 (UpSampling2D) (None, 256, 256, 32) 0           conv2d_276[0][0]
# __________________________________________________________________________________________________
# conv2d_277 (Conv2D)             (None, 256, 256, 16) 2064        up_sampling2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 256, 256, 32) 0           conv2d_254[0][0]
#                                                                  conv2d_277[0][0]
# __________________________________________________________________________________________________
# conv2d_278 (Conv2D)             (None, 256, 256, 16) 4624        concatenate_50[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 256, 256, 16) 2320        conv2d_278[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 256, 256, 1)  17          conv2d_279[0][0]
# ==================================================================================================
# Total params: 7,775,313
# Trainable params: 7,775,313
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/150
# 240/240 [==============================] - 290s 1s/step - loss: 1.5577 - bce_dice_loss: 1.5577 - weighted_binary_crossentropy: 0.5643 - dice_coef: 0.7375 - dice_coef_flat: nan - bce_dice_loss_1: 1.5577 - dice_loss_flat: 0.9934 - val_loss: 1.5604 - val_bce_dice_loss: 1.5604 - val_weighted_binary_crossentropy: 0.5647 - val_dice_coef: 0.7777 - val_dice_coef_flat: nan - val_bce_dice_loss_1: 1.5604 - val_dice_loss_flat: 0.9957
#
# Finished epoch: 0
# {'val_loss': 1.5604026634687498, 'val_bce_dice_loss': 1.560402168750197, 'val_weighted_binary_crossentropy': 0.564708125790636, 'val_dice_coef': 0.7776754523317019, 'val_dice_coef_flat': nan, 'val_bce_dice_loss_1': 1.560402168750197, 'val_dice_loss_flat': 0.9956939873596032, 'loss': 1.5577102774574672, 'bce_dice_loss': 1.557709795653254, 'weighted_binary_crossentropy': 0.564270008257878, 'dice_coef': 0.7375216173134201, 'dice_coef_flat': nan, 'bce_dice_loss_1': 1.557709795653254, 'dice_loss_flat': 0.9934397603074709}
#
# Epoch 00001: val_loss improved from inf to 1.56040, saving model to /data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5
# Epoch 2/150
# 240/240 [==============================] - 275s 1s/step - loss: 1.5644 - bce_dice_loss: 1.5644 - weighted_binary_crossentropy: 0.5645 - dice_coef: 0.7773 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5644 - dice_loss_flat: 0.9998 - val_loss: 1.5639 - val_bce_dice_loss: 1.5639 - val_weighted_binary_crossentropy: 0.5641 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5639 - val_dice_loss_flat: 0.9999
# Finished epoch: 0
# {'val_loss': 1.5604026634687498, 'val_bce_dice_loss': 1.560402168750197, 'val_weighted_binary_crossentropy': 0.564708125790636, 'val_dice_coef': 0.7776754523317019, 'val_dice_coef_flat': nan, 'val_bce_dice_loss_1': 1.560402168750197, 'val_dice_loss_flat': 0.9956939873596032, 'loss': 1.5577102774574672, 'bce_dice_loss': 1.557709795653254, 'weighted_binary_crossentropy': 0.564270008257878, 'dice_coef': 0.7375216173134201, 'dice_coef_flat': nan, 'bce_dice_loss_1': 1.557709795653254, 'dice_loss_flat': 0.9934397603074709}
# Finished epoch: 1
# {'val_loss': 1.5639417777458826, 'val_bce_dice_loss': 1.5639414171377817, 'val_weighted_binary_crossentropy': 0.5640798607715017, 'val_dice_coef': 0.7774341809252898, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5639414171377817, 'val_dice_loss_flat': 0.9998615252474944, 'loss': 1.5643562843402228, 'bce_dice_loss': 1.5643562180300554, 'weighted_binary_crossentropy': 0.5645281901340543, 'dice_coef': 0.7773308898011844, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5643562180300554, 'dice_loss_flat': 0.9998279901842276}
#
# Epoch 00001: val_loss improved from inf to 1.56040, saving model to /data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5
#
# Epoch 00002: val_loss did not improve from 1.56040
# Epoch 3/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5640 - bce_dice_loss: 1.5640 - weighted_binary_crossentropy: 0.5641 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5640 - dice_loss_flat: 0.9998 - val_loss: 1.5643 - val_bce_dice_loss: 1.5643 - val_weighted_binary_crossentropy: 0.5644 - val_dice_coef: 0.7773 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5643 - val_dice_loss_flat: 0.9998
# Finished epoch: 2
# {'val_loss': 1.5642645706733067, 'val_bce_dice_loss': 1.5642642756303151, 'val_weighted_binary_crossentropy': 0.5644236001942773, 'val_dice_coef': 0.7773292856911819, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5642642756303151, 'val_dice_loss_flat': 0.9998406345645586, 'loss': 1.5639692356189092, 'bce_dice_loss': 1.5639690826336543, 'weighted_binary_crossentropy': 0.5641265081125312, 'dice_coef': 0.7776120595633984, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5639690826336543, 'dice_loss_flat': 0.9998425424098969}
#
# Epoch 00002: val_loss did not improve from 1.56040
# Epoch 3/150
#
# Epoch 00003: val_loss did not improve from 1.56040
# Epoch 4/150
# 240/240 [==============================] - 285s 1s/step - loss: 1.5637 - bce_dice_loss: 1.5637 - weighted_binary_crossentropy: 0.5639 - dice_coef: 0.7775 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5637 - dice_loss_flat: 0.9998 - val_loss: 1.5641 - val_bce_dice_loss: 1.5641 - val_weighted_binary_crossentropy: 0.5643 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5641 - val_dice_loss_flat: 0.9998
#
# Epoch 4/150
# Finished epoch: 3
# {'val_loss': 1.5641402445733548, 'val_bce_dice_loss': 1.5641399944821994, 'val_weighted_binary_crossentropy': 0.5643052670105438, 'val_dice_coef': 0.7774499940375487, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5641399944821994, 'val_dice_loss_flat': 0.9998346817990144, 'loss': 1.5637033646305403, 'bce_dice_loss': 1.563703118513028, 'weighted_binary_crossentropy': 0.5638778521504719, 'dice_coef': 0.77745727399985, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.563703118513028, 'dice_loss_flat': 0.9998252123594285}
#
# Epoch 00004: val_loss did not improve from 1.56040
# Epoch 5/150
# 240/240 [==============================] - 283s 1s/step - loss: 1.5651 - bce_dice_loss: 1.5651 - weighted_binary_crossentropy: 0.5653 - dice_coef: 0.7775 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5651 - dice_loss_flat: 0.9998 - val_loss: 1.5644 - val_bce_dice_loss: 1.5644 - val_weighted_binary_crossentropy: 0.5646 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5644 - val_dice_loss_flat: 0.9998
# Finished epoch: 4
# {'val_loss': 1.5643968912462394, 'val_bce_dice_loss': 1.564396641155084, 'val_weighted_binary_crossentropy': 0.5645919184828624, 'val_dice_coef': 0.777434912075599, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564396641155084, 'val_dice_loss_flat': 0.9998047076165676, 'loss': 1.565142465631167, 'bce_dice_loss': 1.5651423506438733, 'weighted_binary_crossentropy': 0.5653117723680529, 'dice_coef': 0.7774593772987525, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5651423506438733, 'dice_loss_flat': 0.9998305278519789}
#
# Epoch 00005: val_loss did not improve from 1.56040
# Epoch 6/150
# 239/240 [============================>.] - ETA: 0s - loss: 1.5665 - bce_dice_loss: 1.5665 - weighted_binary_crossentropy: 0.5667 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5665 - dice_loss_flat: 0.9998Finished epoch: 4
# {'val_loss': 1.5643968912462394, 'val_bce_dice_loss': 1.564396641155084, 'val_weighted_binary_crossentropy': 0.5645919184828624, 'val_dice_coef': 0.777434912075599, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564396641155084, 'val_dice_loss_flat': 0.9998047076165676, 'loss': 1.565142465631167, 'bce_dice_loss': 1.5651423506438733, 'weighted_binary_crossentropy': 0.5653117723680529, 'dice_coef': 0.7774593772987525, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5651423506438733, 'dice_loss_flat': 0.9998305278519789}
# 240/240 [==============================] - 286s 1s/step - loss: 1.5643 - bce_dice_loss: 1.5643 - weighted_binary_crossentropy: 0.5645 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5643 - dice_loss_flat: 0.9998 - val_loss: 1.5648 - val_bce_dice_loss: 1.5648 - val_weighted_binary_crossentropy: 0.5649 - val_dice_coef: 0.7776 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5648 - val_dice_loss_flat: 0.9999
# Finished epoch: 5
# {'val_loss': 1.5647856265306472, 'val_bce_dice_loss': 1.5647853434085846, 'val_weighted_binary_crossentropy': 0.5649199702912786, 'val_dice_coef': 0.7775660882393519, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5647853434085846, 'val_dice_loss_flat': 0.999865324050188, 'loss': 1.5642712848881881, 'bce_dice_loss': 1.564270983884732, 'weighted_binary_crossentropy': 0.5644565622176743, 'dice_coef': 0.7777419087787469, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.564270983884732, 'dice_loss_flat': 0.9998143946131071}
#
# Epoch 00006: val_loss did not improve from 1.56040
# Epoch 7/150
# 240/240 [==============================] - 285s 1s/step - loss: 1.5637 - bce_dice_loss: 1.5637 - weighted_binary_crossentropy: 0.5638 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5637 - dice_loss_flat: 0.9998 - val_loss: 1.5637 - val_bce_dice_loss: 1.5637 - val_weighted_binary_crossentropy: 0.5639 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5637 - val_dice_loss_flat: 0.9998
# Finished epoch: 6
# {'val_loss': 1.5636834474901358, 'val_bce_dice_loss': 1.5636833749711514, 'val_weighted_binary_crossentropy': 0.5638595284874707, 'val_dice_coef': 0.7774358483652274, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5636833749711514, 'val_dice_loss_flat': 0.9998237756391366, 'loss': 1.5636908868948618, 'bce_dice_loss': 1.5636905213197072, 'weighted_binary_crossentropy': 0.5638447147755262, 'dice_coef': 0.7775713774065177, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5636905213197072, 'dice_loss_flat': 0.9998457781970501}
#
# Epoch 00007: val_loss did not improve from 1.56040
# Epoch 8/150
# 240/240 [==============================] - 281s 1s/step - loss: 1.5637 - bce_dice_loss: 1.5637 - weighted_binary_crossentropy: 0.5638 - dice_coef: 0.7774 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5637 - dice_loss_flat: 0.9998 - val_loss: 1.5642 - val_bce_dice_loss: 1.5642 - val_weighted_binary_crossentropy: 0.5643 - val_dice_coef: 0.7776 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5642 - val_dice_loss_flat: 0.9999
# Finished epoch: 7
# {'val_loss': 1.5641695767641068, 'val_bce_dice_loss': 1.5641694515943527, 'val_weighted_binary_crossentropy': 0.5643124828289728, 'val_dice_coef': 0.7775654539465904, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5641694515943527, 'val_dice_loss_flat': 0.9998569262524446, 'loss': 1.5636744817097983, 'bce_dice_loss': 1.5636741233368714, 'weighted_binary_crossentropy': 0.5638336276941118, 'dice_coef': 0.7774497558673222, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5636741233368714, 'dice_loss_flat': 0.9998404448231061}
# Finished epoch: 6
# {'val_loss': 1.5636834474901358, 'val_bce_dice_loss': 1.5636833749711514, 'val_weighted_binary_crossentropy': 0.5638595284874707, 'val_dice_coef': 0.7774358483652274, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5636833749711514, 'val_dice_loss_flat': 0.9998237756391366, 'loss': 1.5636908868948618, 'bce_dice_loss': 1.5636905213197072, 'weighted_binary_crossentropy': 0.5638447147755262, 'dice_coef': 0.7775713774065177, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5636905213197072, 'dice_loss_flat': 0.9998457781970501}
#
# Epoch 00008: val_loss did not improve from 1.56040
# Epoch 9/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5597 - bce_dice_loss: 1.5597 - weighted_binary_crossentropy: 0.5640 - dice_coef: 0.7773 - dice_coef_flat: nan - bce_dice_loss_1: 1.5597 - dice_loss_flat: 0.9957 - val_loss: 1.5642 - val_bce_dice_loss: 1.5642 - val_weighted_binary_crossentropy: 0.5643 - val_dice_coef: 0.7773 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5642 - val_dice_loss_flat: 0.9998
# Finished epoch: 8
# {'val_loss': 1.5641789431373279, 'val_bce_dice_loss': 1.5641786227623622, 'val_weighted_binary_crossentropy': 0.564349557220703, 'val_dice_coef': 0.7773177675902844, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5641786227623622, 'val_dice_loss_flat': 0.9998290374875068, 'loss': 1.5597360674733236, 'bce_dice_loss': 1.5597357610061071, 'weighted_binary_crossentropy': 0.5640483111060618, 'dice_coef': 0.7773010092477004, 'dice_coef_flat': nan, 'bce_dice_loss_1': 1.5597357610061071, 'dice_loss_flat': 0.995687402288119}
# Finished epoch: 7
# Epoch 00009: val_loss did not improve from 1.56040
# Epoch 10/150
# 239/240 [============================>.] - ETA: 0s - loss: 1.5661 - bce_dice_loss: 1.5661 - weighted_binary_crossentropy: 0.5663 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5661 - dice_loss_flat: 0.9999
# Epoch 00009: val_loss did not improve from 1.56040
# Epoch 10/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5641 - bce_dice_loss: 1.5641 - weighted_binary_crossentropy: 0.5643 - dice_coef: 0.7774 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5641 - dice_loss_flat: 0.9999 - val_loss: 1.5647 - val_bce_dice_loss: 1.5647 - val_weighted_binary_crossentropy: 0.5648 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5647 - val_dice_loss_flat: 0.9998
# Finished epoch: 9
# {'val_loss': 1.5646744519472122, 'val_bce_dice_loss': 1.5646739510198435, 'val_weighted_binary_crossentropy': 0.5648289577880253, 'val_dice_coef': 0.7774380991856257, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5646739510198435, 'val_dice_loss_flat': 0.9998449715475242, 'loss': 1.5641256148616474, 'bce_dice_loss': 1.564125375946363, 'weighted_binary_crossentropy': 0.5642726097508178, 'dice_coef': 0.7774472263952096, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.564125375946363, 'dice_loss_flat': 0.9998527236282826}
#
# Epoch 00010: val_loss did not improve from 1.56040
# Epoch 11/150
# 240/240 [==============================] - 283s 1s/step - loss: 1.5645 - bce_dice_loss: 1.5645 - weighted_binary_crossentropy: 0.5647 - dice_coef: 0.7773 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5645 - dice_loss_flat: 0.9998 - val_loss: 1.5642 - val_bce_dice_loss: 1.5642 - val_weighted_binary_crossentropy: 0.5643 - val_dice_coef: 0.7776 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5642 - val_dice_loss_flat: 0.9998
#
# Epoch 00010: val_loss did not improve from 1.56040
# Epoch 11/150
# Finished epoch: 10
# {'val_loss': 1.56419424811999, 'val_bce_dice_loss': 1.5641940593719483, 'val_weighted_binary_crossentropy': 0.5643499443831388, 'val_dice_coef': 0.7775689996778965, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5641940593719483, 'val_dice_loss_flat': 0.9998440740009149, 'loss': 1.564512374252081, 'bce_dice_loss': 1.5645120379825432, 'weighted_binary_crossentropy': 0.5646889199318442, 'dice_coef': 0.777319074422121, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5645120379825432, 'dice_loss_flat': 0.9998230653504531}
#
# Epoch 00011: val_loss did not improve from 1.56040
# Epoch 12/150
# 240/240 [==============================] - 281s 1s/step - loss: 1.5647 - bce_dice_loss: 1.5647 - weighted_binary_crossentropy: 0.5648 - dice_coef: 0.7774 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5647 - dice_loss_flat: 0.9999 - val_loss: 1.5643 - val_bce_dice_loss: 1.5643 - val_weighted_binary_crossentropy: 0.5644 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5643 - val_dice_loss_flat: 0.9999
# Finished epoch: 11
# {'val_loss': 1.5642833227912585, 'val_bce_dice_loss': 1.5642830396691958, 'val_weighted_binary_crossentropy': 0.5644219680010186, 'val_dice_coef': 0.7774359737833341, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5642830396691958, 'val_dice_loss_flat': 0.9998610183596611, 'loss': 1.5646591211358707, 'bce_dice_loss': 1.5646588732798894, 'weighted_binary_crossentropy': 0.5647961333607479, 'dice_coef': 0.7774459076424439, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5646588732798894, 'dice_loss_flat': 0.9998627011974652}
#
# Epoch 00012: val_loss did not improve from 1.56040
# Epoch 13/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5642 - bce_dice_loss: 1.5642 - weighted_binary_crossentropy: 0.5643 - dice_coef: 0.7773 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5642 - dice_loss_flat: 0.9999 - val_loss: 1.5642 - val_bce_dice_loss: 1.5642 - val_weighted_binary_crossentropy: 0.5644 - val_dice_coef: 0.7775 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5642 - val_dice_loss_flat: 0.9999
# Finished epoch: 12
# {'val_loss': 1.5642128884792328, 'val_bce_dice_loss': 1.564212686320146, 'val_weighted_binary_crossentropy': 0.5643522397362782, 'val_dice_coef': 0.7775448640187581, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564212686320146, 'val_dice_loss_flat': 0.9998604026933511, 'loss': 1.5641791358590127, 'bce_dice_loss': 1.5641788919766744, 'weighted_binary_crossentropy': 0.5643235273853254, 'dice_coef': 0.7773095625142257, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5641788919766744, 'dice_loss_flat': 0.9998553248743216}
#
# Epoch 00013: val_loss did not improve from 1.56040
# Epoch 14/150
#
# Epoch 00012: val_loss did not improve from 1.56040
# Epoch 13/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5643 - bce_dice_loss: 1.5643 - weighted_binary_crossentropy: 0.5644 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5643 - dice_loss_flat: 0.9999 - val_loss: 1.5567 - val_bce_dice_loss: 1.5567 - val_weighted_binary_crossentropy: 0.5568 - val_dice_coef: 0.7777 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5567 - val_dice_loss_flat: 0.9998
# Finished epoch: 13
# {'val_loss': 1.556675838927428, 'val_bce_dice_loss': 1.5566756029923756, 'val_weighted_binary_crossentropy': 0.5568347290352297, 'val_dice_coef': 0.7777086834112803, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5566756029923756, 'val_dice_loss_flat': 0.9998408332467079, 'loss': 1.564264258245627, 'bce_dice_loss': 1.5642641976475715, 'weighted_binary_crossentropy': 0.5644052252736098, 'dice_coef': 0.7776759090522926, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5642641976475715, 'dice_loss_flat': 0.999858949581782}
#
# Epoch 00014: val_loss improved from 1.56040 to 1.55668, saving model to /data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5
# Epoch 15/150
# 240/240 [==============================] - 280s 1s/step - loss: 1.5639 - bce_dice_loss: 1.5639 - weighted_binary_crossentropy: 0.5641 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5639 - dice_loss_flat: 0.9998 - val_loss: 1.5641 - val_bce_dice_loss: 1.5641 - val_weighted_binary_crossentropy: 0.5642 - val_dice_coef: 0.7773 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5641 - val_dice_loss_flat: 0.9998
#
# Epoch 00014: val_loss improved from 1.56040 to 1.55668, saving model to /data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5
# Finished epoch: 14
# {'val_loss': 1.5640965764721235, 'val_bce_dice_loss': 1.5640961532791455, 'val_weighted_binary_crossentropy': 0.5642499663110356, 'val_dice_coef': 0.7773120880126954, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5640961532791455, 'val_dice_loss_flat': 0.9998461397985617, 'loss': 1.5639390369256339, 'bce_dice_loss': 1.5639385893940925, 'weighted_binary_crossentropy': 0.5640899732029842, 'dice_coef': 0.7776771960159142, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5639385893940925, 'dice_loss_flat': 0.9998485711713632}
#
# Epoch 00015: val_loss did not improve from 1.55668
# Epoch 16/150
# 240/240 [==============================] - 281s 1s/step - loss: 1.5642 - bce_dice_loss: 1.5642 - weighted_binary_crossentropy: 0.5644 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5642 - dice_loss_flat: 0.9998 - val_loss: 1.5643 - val_bce_dice_loss: 1.5643 - val_weighted_binary_crossentropy: 0.5645 - val_dice_coef: 0.7775 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5643 - val_dice_loss_flat: 0.9998
# Finished epoch: 15
# {'val_loss': 1.5643249534070491, 'val_bce_dice_loss': 1.564324901998043, 'val_weighted_binary_crossentropy': 0.564528542321447, 'val_dice_coef': 0.777482962111632, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564324901998043, 'val_dice_loss_flat': 0.9997963177661101, 'loss': 1.5642103652159374, 'bce_dice_loss': 1.5642099698384604, 'weighted_binary_crossentropy': 0.5643615979866202, 'dice_coef': 0.7775692097842694, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5642099698384604, 'dice_loss_flat': 0.9998483334978422}
#
# Epoch 00016: val_loss did not improve from 1.55668
# Epoch 17/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5644 - bce_dice_loss: 1.5644 - weighted_binary_crossentropy: 0.5645 - dice_coef: 0.7775 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5644 - dice_loss_flat: 0.9999 - val_loss: 1.5496 - val_bce_dice_loss: 1.5496 - val_weighted_binary_crossentropy: 0.5540 - val_dice_coef: 0.7776 - val_dice_coef_flat: nan - val_bce_dice_loss_1: 1.5496 - val_dice_loss_flat: 0.9957
# Finished epoch: 15
# {'val_loss': 1.5643249534070491, 'val_bce_dice_loss': 1.564324901998043, 'val_weighted_binary_crossentropy': 0.564528542321447, 'val_dice_coef': 0.777482962111632, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564324901998043, 'val_dice_loss_flat': 0.9997963177661101, 'loss': 1.5642103652159374, 'bce_dice_loss': 1.5642099698384604, 'weighted_binary_crossentropy': 0.5643615979866202, 'dice_coef': 0.7775692097842694, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5642099698384604, 'dice_loss_flat': 0.9998483334978422}
#
# Epoch 00016: val_loss did not improve from 1.55668
# Epoch 17/150
# Finished epoch: 16
# {'val_loss': 1.5496495678220505, 'val_bce_dice_loss': 1.5496492628449503, 'val_weighted_binary_crossentropy': 0.5539506703746123, 'val_dice_coef': 0.77756678784887, 'val_dice_coef_flat': nan, 'val_bce_dice_loss_1': 1.5496492628449503, 'val_dice_loss_flat': 0.9956985369324685, 'loss': 1.5643874992926916, 'bce_dice_loss': 1.5643870095411936, 'weighted_binary_crossentropy': 0.5645267892357272, 'dice_coef': 0.7774807984630266, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5643870095411936, 'dice_loss_flat': 0.9998601915935675}
#
# Epoch 00017: val_loss improved from 1.55668 to 1.54965, saving model to /data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5
# Epoch 18/150
# 240/240 [==============================] - 280s 1s/step - loss: 1.5637 - bce_dice_loss: 1.5637 - weighted_binary_crossentropy: 0.5638 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5637 - dice_loss_flat: 0.9999 - val_loss: 1.5640 - val_bce_dice_loss: 1.5640 - val_weighted_binary_crossentropy: 0.5641 - val_dice_coef: 0.7775 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5640 - val_dice_loss_flat: 0.9998
# Finished epoch: 17
# {'val_loss': 1.5639869838953018, 'val_bce_dice_loss': 1.5639867171645165, 'val_weighted_binary_crossentropy': 0.5641406072575289, 'val_dice_coef': 0.7775462421278159, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5639867171645165, 'val_dice_loss_flat': 0.9998460829257965, 'loss': 1.5636729846398036, 'bce_dice_loss': 1.5636729354659715, 'weighted_binary_crossentropy': 0.5638158244177854, 'dice_coef': 0.777586733798186, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5636729354659715, 'dice_loss_flat': 0.9998570593694845}
#
# Epoch 00018: val_loss did not improve from 1.54965
# Epoch 19/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5641 - bce_dice_loss: 1.5641 - weighted_binary_crossentropy: 0.5642 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5641 - dice_loss_flat: 0.9999 - val_loss: 1.5648 - val_bce_dice_loss: 1.5648 - val_weighted_binary_crossentropy: 0.5649 - val_dice_coef: 0.7776 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5648 - val_dice_loss_flat: 0.9998
# Finished epoch: 18
# {'val_loss': 1.5647750342885653, 'val_bce_dice_loss': 1.564774749179681, 'val_weighted_binary_crossentropy': 0.5649285907876522, 'val_dice_coef': 0.7775770430763562, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564774749179681, 'val_dice_loss_flat': 0.9998461306095123, 'loss': 1.564100810388724, 'bce_dice_loss': 1.5641006648540496, 'weighted_binary_crossentropy': 0.5642272927914747, 'dice_coef': 0.7777081718047459, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5641006648540496, 'dice_loss_flat': 0.999873332430919}
#
# Epoch 00019: val_loss did not improve from 1.54965
# Epoch 20/150
# 240/240 [==============================] - 282s 1s/step - loss: 1.5647 - bce_dice_loss: 1.5647 - weighted_binary_crossentropy: 0.5648 - dice_coef: 0.7776 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5647 - dice_loss_flat: 0.9999 - val_loss: 1.5645 - val_bce_dice_loss: 1.5645 - val_weighted_binary_crossentropy: 0.5647 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5645 - val_dice_loss_flat: 0.9998
# Finished epoch: 19
# {'val_loss': 1.5645386690894763, 'val_bce_dice_loss': 1.5645383514463902, 'val_weighted_binary_crossentropy': 0.5647358021764376, 'val_dice_coef': 0.7774499647319317, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5645383514463902, 'val_dice_loss_flat': 0.9998024868468444, 'loss': 1.5646661986907324, 'bce_dice_loss': 1.5646660347779593, 'weighted_binary_crossentropy': 0.5648080429139858, 'dice_coef': 0.7775731357435386, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5646660347779593, 'dice_loss_flat': 0.9998579449951649}
#
# Epoch 00020: val_loss did not improve from 1.54965
# Epoch 21/150
# 240/240 [==============================] - 283s 1s/step - loss: 1.5645 - bce_dice_loss: 1.5645 - weighted_binary_crossentropy: 0.5646 - dice_coef: 0.7774 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5645 - dice_loss_flat: 0.9998 - val_loss: 1.5642 - val_bce_dice_loss: 1.5642 - val_weighted_binary_crossentropy: 0.5643 - val_dice_coef: 0.7776 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5642 - val_dice_loss_flat: 0.9998
# Finished epoch: 20
# {'val_loss': 1.564189515511195, 'val_bce_dice_loss': 1.5641892070571581, 'val_weighted_binary_crossentropy': 0.5643404343243067, 'val_dice_coef': 0.7775734176238378, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5641892070571581, 'val_dice_loss_flat': 0.9998487204313278, 'loss': 1.564450882623593, 'bce_dice_loss': 1.5644505880773067, 'weighted_binary_crossentropy': 0.5646317845753704, 'dice_coef': 0.7774154531459013, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5644505880773067, 'dice_loss_flat': 0.9998187822600205}
#
# Epoch 00021: val_loss did not improve from 1.54965
# Epoch 22/150
# 240/240 [==============================] - 284s 1s/step - loss: 1.5639 - bce_dice_loss: 1.5639 - weighted_binary_crossentropy: 0.5641 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5639 - dice_loss_flat: 0.9999 - val_loss: 1.5643 - val_bce_dice_loss: 1.5643 - val_weighted_binary_crossentropy: 0.5644 - val_dice_coef: 0.7775 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5643 - val_dice_loss_flat: 0.9998
# Finished epoch: 21
# {'val_loss': 1.5642589484651883, 'val_bce_dice_loss': 1.5642586544156074, 'val_weighted_binary_crossentropy': 0.5644176384841557, 'val_dice_coef': 0.7774593052764733, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5642586544156074, 'val_dice_loss_flat': 0.9998410026232402, 'loss': 1.5639360050360362, 'bce_dice_loss': 1.5639357402920724, 'weighted_binary_crossentropy': 0.5640838960088634, 'dice_coef': 0.7776986174285412, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5639357402920724, 'dice_loss_flat': 0.9998517932991187}
#
# Epoch 00022: val_loss did not improve from 1.54965
# Epoch 23/150
# 240/240 [==============================] - 287s 1s/step - loss: 1.5643 - bce_dice_loss: 1.5643 - weighted_binary_crossentropy: 0.5645 - dice_coef: 0.7774 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5643 - dice_loss_flat: 0.9998 - val_loss: 1.5631 - val_bce_dice_loss: 1.5631 - val_weighted_binary_crossentropy: 0.5633 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5631 - val_dice_loss_flat: 0.9998
# Finished epoch: 22
# {'val_loss': 1.5631068443258604, 'val_bce_dice_loss': 1.5631067077318828, 'val_weighted_binary_crossentropy': 0.5632641156679408, 'val_dice_coef': 0.7774491466581821, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5631067077318828, 'val_dice_loss_flat': 0.9998425451417764, 'loss': 1.5642578860123952, 'bce_dice_loss': 1.564257739732663, 'weighted_binary_crossentropy': 0.5644751884312427, 'dice_coef': 0.7774375615020593, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.564257739732663, 'dice_loss_flat': 0.9997825153172016}
#
# Epoch 00022: val_loss did not improve from 1.54965
# Epoch 23/150
#
# Epoch 00023: val_loss did not improve from 1.54965
# Epoch 24/150
# 240/240 [==============================] - 281s 1s/step - loss: 1.5637 - bce_dice_loss: 1.5637 - weighted_binary_crossentropy: 0.5639 - dice_coef: 0.7777 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.5637 - dice_loss_flat: 0.9998 - val_loss: 1.5646 - val_bce_dice_loss: 1.5646 - val_weighted_binary_crossentropy: 0.5648 - val_dice_coef: 0.7774 - val_dice_coef_flat: 0.0000e+00 - val_bce_dice_loss_1: 1.5646 - val_dice_loss_flat: 0.9998
# Finished epoch: 23
# {'val_loss': 1.5646358971794447, 'val_bce_dice_loss': 1.564635705947876, 'val_weighted_binary_crossentropy': 0.5647962939673259, 'val_dice_coef': 0.7774409562349319, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.564635705947876, 'val_dice_loss_flat': 0.9998393838604291, 'loss': 1.5636916364232698, 'bce_dice_loss': 1.5636914893984795, 'weighted_binary_crossentropy': 0.5638649437188481, 'dice_coef': 0.7776968869070212, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.5636914893984795, 'dice_loss_flat': 0.999826509008805}
#
# Epoch 00024: val_loss did not improve from 1.54965
# Epoch 25/150
#
# {'val_loss': 1.5631068443258604, 'val_bce_dice_loss': 1.5631067077318828, 'val_weighted_binary_crossentropy': 0.5632641156679408, 'val_dice_coef': 0.7774491466581821, 'val_dice_coef_flat': 0.0, 'val_bce_dice_loss_1': 1.5631067077318828, 'val_dice_loss_flat': 0.9998425451417764, 'loss': 1.5642578860123952, 'bce_dice_loss': 1.564257739732663, 'weighted_binary_crossentropy': 0.5644751884312427, 'dice_coef': 0.7774375615020593, 'dice_coef_flat': 0.0, 'bce_dice_loss_1': 1.564257739732663, 'dice_loss_flat': 0.9997825153172016}
#  41/240 [====>.........................] - ETA: 2:13 - loss: 1.7391 - bce_dice_loss: 1.7391 - weighted_binary_crossentropy: 0.7392 - dice_coef: 0.7857 - dice_coef_flat: 0.0000e+00 - bce_dice_loss_1: 1.7391 - dice_loss_flat: 0.9999
# Process ForkPoolWorker-1240:
# Process ForkPoolWorker-1237:
# Process ForkPoolWorker-1243:
# Process ForkPoolWorker-1235:
# Process ForkPoolWorker-1236:
# Process ForkPoolWorker-1241:
# Process ForkPoolWorker-1234:
# Traceback (most recent call last):
# Process ForkPoolWorker-1231:
# Traceback (most recent call last):
# Process ForkPoolWorker-1227:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-1229:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1242:
# Process ForkPoolWorker-1228:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1230:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# Process ForkPoolWorker-1225:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Process ForkPoolWorker-1233:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 284, in _augmentation
#     mask = ndimage.rotate(mask,angle, axes=(1, 2), order=0, reshape=False)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1224:
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-1226:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 284, in _augmentation
#     mask = ndimage.rotate(mask,angle, axes=(1, 2), order=0, reshape=False)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 532, in shift
#     _nd_image.zoom_shift(filtered, None, shift, output, order, mode, cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# KeyboardInterrupt
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 283, in _augmentation
#     volume = ndimage.rotate(volume,angle, axes=(1, 2), order=0, reshape=False, cval=cval)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 279, in _augmentation
#     mask = ndimage.shift(mask, shift, order=0)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 278, in _augmentation
#     volume = ndimage.shift(volume, shift, order=0, cval=cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 532, in shift
#     _nd_image.zoom_shift(filtered, None, shift, output, order, mode, cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 278, in _augmentation
#     volume = ndimage.shift(volume, shift, order=0, cval=cval)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 283, in _augmentation
#     volume = ndimage.rotate(volume,angle, axes=(1, 2), order=0, reshape=False, cval=cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 532, in shift
#     _nd_image.zoom_shift(filtered, None, shift, output, order, mode, cval)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 284, in _augmentation
#     mask = ndimage.rotate(mask,angle, axes=(1, 2), order=0, reshape=False)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 279, in _augmentation
#     mask = ndimage.shift(mask, shift, order=0)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
# Process ForkPoolWorker-1232:
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 532, in shift
#     _nd_image.zoom_shift(filtered, None, shift, output, order, mode, cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-8b7821b40d0d> in <module>
#       9              steps_per_epoch=steps_per_epoch,
#      10              log_dir=log_dir,
# ---> 11              epochs=epochs)
#
# ~/work/siim_pneumo/train_util.py in train(model, train_gen, val_gen, steps_per_epoch, optimizer, log_dir, epochs, loss, metrics, lr_mode, reduce_lr_factor, reduce_lr_patience, validation_steps)
#     111         validation_steps=validation_steps,
#     112         callbacks=callbacks,
# --> 113         use_multiprocessing=True # Don't use multiprocessing https://keunwoochoi.wordpress.com/2017/08/24/tip-fit_generator-in-keras-how-to-parallelise-correctly/
#     114         )
#     115
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     175             batch_index = 0
#     176             while steps_done < steps_per_epoch:
# --> 177                 generator_output = next(output_generator)
#     178
#     179                 if not hasattr(generator_output, '__len__'):
#
# /opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     576         try:
#     577             while self.is_running():
# --> 578                 inputs = self.queue.get(block=True).get()
#     579                 self.queue.task_done()
#     580                 if inputs is not None:
#
# /opt/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /opt/anaconda3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /opt/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /opt/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/opt/anaconda3/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 143, in __getitem__
#     img, mask = _augmentation(img, mask, flip=self.flip, maxshift=self.maxshift, maxrotate=self.maxrotate, flag2d=True)
#   File "/home/yusuke/work/siim_pneumo/data_generator.py", line 283, in _augmentation
#     volume = ndimage.rotate(volume,angle, axes=(1, 2), order=0, reshape=False, cval=cval)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 739, in rotate
#     cval, prefilter)
#   File "/opt/anaconda3/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 480, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt

# %% [markdown]
# ## See training results

# %%
# laod model
from keras.models import load_model
# model_path = '/data/kits_log/2019_0724_0242/best_weights.hdf5'
model_path = '/data/pneumo_log/val_1//2019_0803_1730/best_weights.hdf5'
custom_objects = {
                'weighted_binary_crossentropy':loss_util.create_weighted_binary_crossentropy(zero_weight, one_weight),
           'dice_coef':loss_util.create_dice_coef(),
           'dice_coef_flat':loss_util.dice_coef_flat,
           'bce_dice_loss':loss_util.bce_dice_loss,
           'dice_loss_flat':loss_util.dice_loss_flat,}
model = load_model(model_path, custom_objects=custom_objects)

# %%
images, masks = val_gen.__getitem__(0)
pred = model.predict(images)
index = 7

i = np.squeeze(images[index])
m = np.squeeze(masks[index])
p = np.squeeze(pred[index])
print(np.unique(p))
# Out:
# [0.]

# %%
plt.imshow(m)

# %%
m = np.expand_dims(m, axis=0)
p = np.expand_dims(p, axis=0)
m = np.expand_dims(m, axis=-1)
p = np.expand_dims(p, axis=-1)

# %%
m = np.array(m, dtype=np.float32)
loss_flat = loss_util.dice_coef_flat(m, p)
dice_coef = loss_util.create_dice_coef()
dice_value = dice_coef(m, p)

# %%
import keras.backend as K
K.get_value(loss)
# Out:
# 0.0

# %%
K.get_value(dice_value)
# Out:
# 1.0

# %%
m.shape
# Out:
# (1, 256, 256, 1)
